# %% [markdown]
# <a href="https://colab.research.google.com/github/saquibmohiuddin/Coursera_Capstone/blob/master/Final_Week_3_Assignment_Segmenting_and_Clustering_Neighborhoods_in_Toronto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing Data into variable 'URL'

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %% [markdown]
# ## Importing and Installing all necessary libraries

# %%
# !pip install beautifulsoup4
# !pip install lxml
import requests 
import pandas as pd 
import numpy as np 
import random 

# !conda install -c conda-forge geopy --yes # installing google maps geocoding api
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 


from IPython.display import display_html
import pandas as pd
import numpy as np
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
from bs4 import BeautifulSoup
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
# /bin/bash: conda: command not found
# /bin/bash: conda: command not found
# Folium installed
# Libraries imported.

# %%
df = pd.read_html(url, header = 0)
df
# Out:
# [    Postal Code  ...                                      Neighbourhood
#  0           M1A  ...                                       Not assigned
#  1           M2A  ...                                       Not assigned
#  2           M3A  ...                                          Parkwoods
#  3           M4A  ...                                   Victoria Village
#  4           M5A  ...                          Regent Park, Harbourfront
#  ..          ...  ...                                                ...
#  175         M5Z  ...                                       Not assigned
#  176         M6Z  ...                                       Not assigned
#  177         M7Z  ...                                       Not assigned
#  178         M8Z  ...  Mimico NW, The Queensway West, South of Bloor,...
#  179         M9Z  ...                                       Not assigned
#
#  [180 rows x 3 columns],
# ...

# %%
len(df)
# Out:
# 3

# %% [markdown]
# ## Vieweing the first table

# %%
df[0]
# Out:
#     Postal Code  ...                                      Neighbourhood
# 0           M1A  ...                                       Not assigned
# 1           M2A  ...                                       Not assigned
# 2           M3A  ...                                          Parkwoods
# 3           M4A  ...                                   Victoria Village
# 4           M5A  ...                          Regent Park, Harbourfront
# ..          ...  ...                                                ...
# 175         M5Z  ...                                       Not assigned
# 176         M6Z  ...                                       Not assigned
# 177         M7Z  ...                                       Not assigned
# 178         M8Z  ...  Mimico NW, The Queensway West, South of Bloor,...
# 179         M9Z  ...                                       Not assigned
#
# [180 rows x 3 columns]

# %% [markdown]
# ## Selecting the First table and loading into Data Frame

# %%
df_toronto = df[0]
df_toronto.head()
# Out:
#   Postal Code           Borough              Neighbourhood
# 0         M1A      Not assigned               Not assigned
# 1         M2A      Not assigned               Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
print(df_toronto[['Borough','Neighbourhood']]) # Accessing only 2 columns
# Out:
#               Borough                                      Neighbourhood
# 0        Not assigned                                       Not assigned
# 1        Not assigned                                       Not assigned
# 2          North York                                          Parkwoods
# 3          North York                                   Victoria Village
# 4    Downtown Toronto                          Regent Park, Harbourfront
# ..                ...                                                ...
# 175      Not assigned                                       Not assigned
# 176      Not assigned                                       Not assigned
# 177      Not assigned                                       Not assigned
# 178         Etobicoke  Mimico NW, The Queensway West, South of Bloor,...
# 179      Not assigned                                       Not assigned
#
# [180 rows x 2 columns]

# %% [markdown]
# ## Cleaning up the Data

# %%
df_filtered = df_toronto[df_toronto['Borough'] != 'Not assigned']
df_filtered.head()
# Out:
#   Postal Code           Borough                                Neighbourhood
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
df2 = df_filtered.groupby(['Postal Code','Borough'], sort=False).agg(', '.join)
df2.reset_index(inplace=True)

df2['Neighbourhood'] = np.where(df2['Neighbourhood'] == 'Not assigned',df2['Borough'], df2['Neighbourhood'])

df2
# Out:
#     Postal Code  ...                                      Neighbourhood
# 0           M3A  ...                                          Parkwoods
# 1           M4A  ...                                   Victoria Village
# 2           M5A  ...                          Regent Park, Harbourfront
# 3           M6A  ...                   Lawrence Manor, Lawrence Heights
# 4           M7A  ...        Queen's Park, Ontario Provincial Government
# ..          ...  ...                                                ...
# 98          M8X  ...      The Kingsway, Montgomery Road, Old Mill North
# 99          M4Y  ...                               Church and Wellesley
# 100         M7Y  ...  Business reply mail Processing Centre, South C...
# 101         M8Y  ...  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102         M8Z  ...  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %%
df2.shape
# Out:
# (103, 3)

# %% [markdown]
# ## Importing the Geo Location files and assigning a variable

# %%
location = pd.read_csv('https://cocl.us/Geospatial_data')
location.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# ## Merging the tables

# %%
df3 = pd.merge(df2,location,on='Postal Code')
df3.head()
# Out:
#   Postal Code           Borough  ...   Latitude  Longitude
# 0         M3A        North York  ...  43.753259 -79.329656
# 1         M4A        North York  ...  43.725882 -79.315572
# 2         M5A  Downtown Toronto  ...  43.654260 -79.360636
# 3         M6A        North York  ...  43.718518 -79.464763
# 4         M7A  Downtown Toronto  ...  43.662301 -79.389494
#
# [5 rows x 5 columns]

# %% [markdown]
# ## Loading all Borough with 'Toronto' into a cleaned dataframe

# %%
Cleaned_df = df3[df3['Borough'].str.contains('Toronto',regex=False)]
Cleaned_df
# Out:
#     Postal Code           Borough  ...   Latitude  Longitude
# 2           M5A  Downtown Toronto  ...  43.654260 -79.360636
# 4           M7A  Downtown Toronto  ...  43.662301 -79.389494
# 9           M5B  Downtown Toronto  ...  43.657162 -79.378937
# 15          M5C  Downtown Toronto  ...  43.651494 -79.375418
# 19          M4E      East Toronto  ...  43.676357 -79.293031
# 20          M5E  Downtown Toronto  ...  43.644771 -79.373306
# 24          M5G  Downtown Toronto  ...  43.657952 -79.387383
# 25          M6G  Downtown Toronto  ...  43.669542 -79.422564
# 30          M5H  Downtown Toronto  ...  43.650571 -79.384568
# 31          M6H      West Toronto  ...  43.669005 -79.442259
# 36          M5J  Downtown Toronto  ...  43.640816 -79.381752
# 37          M6J      West Toronto  ...  43.647927 -79.419750
# 41          M4K      East Toronto  ...  43.679557 -79.352188
# 42          M5K  Downtown Toronto  ...  43.647177 -79.381576
# ...

# %% [markdown]
# ## Visualizing all neighbourhoods

# %%
map_toronto = folium.Map(location=[43.651070,-79.347015],zoom_start=14)

for lat,lng,borough,neighbourhood in zip(Cleaned_df['Latitude'],Cleaned_df['Longitude'],Cleaned_df['Borough'],Cleaned_df['Neighbourhood']):
    label = f'{neighbourhood}, {borough}'
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
    [lat,lng],
    radius=5,
    popup=label,
    color='#030c0e',
    fill=True,
    fill_color='#030c0e',
    fill_opacity=0.5,
    parse_html=False).add_to(map_toronto)
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Perform Clustering via K Means algorithm

# %%
k=5
toronto_clustering = Cleaned_df.drop(['Postal Code','Borough','Neighbourhood'],1)
kmeans = KMeans(n_clusters = k,random_state=0).fit(toronto_clustering)
kmeans.labels_
Cleaned_df.insert(0, 'Cluster Labels', kmeans.labels_)

# %% [markdown]
# # Verifying the Data Frame

# %%
Cleaned_df
# Out:
#      Cluster Labels Postal Code  ...   Latitude  Longitude
# 2                 0         M5A  ...  43.654260 -79.360636
# 4                 0         M7A  ...  43.662301 -79.389494
# 9                 0         M5B  ...  43.657162 -79.378937
# 15                0         M5C  ...  43.651494 -79.375418
# 19                1         M4E  ...  43.676357 -79.293031
# 20                0         M5E  ...  43.644771 -79.373306
# 24                0         M5G  ...  43.657952 -79.387383
# 25                3         M6G  ...  43.669542 -79.422564
# 30                0         M5H  ...  43.650571 -79.384568
# 31                2         M6H  ...  43.669005 -79.442259
# 36                0         M5J  ...  43.640816 -79.381752
# 37                3         M6J  ...  43.647927 -79.419750
# 41                1         M4K  ...  43.679557 -79.352188
# 42                0         M5K  ...  43.647177 -79.381576
# 43                3         M6K  ...  43.636847 -79.428191
# ...

# %% [markdown]
# # Plotting Map with ranbow color scheme

# %%
clustering_map = folium.Map(location=[43.651070,-79.347015],zoom_start=12)

x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# assignign markers 
markers_colors = []
for lat, lon, neighbourhood, cluster in zip(Cleaned_df['Latitude'], Cleaned_df['Longitude'], Cleaned_df['Neighbourhood'], Cleaned_df['Cluster Labels']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.4).add_to(clustering_map)
       
clustering_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
